# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoKitchell/CompNeuroMidterm/blob/main/Biol133L_ps1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problem Set 1**
# ## Due Thursday, Oct 7th at 11 AM

# %% [markdown]
# ### **Summary**
#  This problem set is designed to engage your creativity, critical thinking, resourcefulness, coding skills, and fluency with the topics that we have covered during this semester.

# %% [markdown]
# ### **Instructions:**
# •	You may use any resource you would like, including the internet, your classmates, TA, or instructor. Slack #questions is a good channel.
#
# •	Cite all sources that you used and the information they provided you.
#
# •	If you ask someone a question, make it as specific as possible (Not “How do I solve problem 1?” but “How can I represent this input as a vector?”).
#
# •	If someone asks you a question, give them the minimal information that gets them unstuck; note their name and the help you gave. You are not obligated to answer any question.
#
# •	If you cannot solve a problem, describe your progress and your thought process where you got stuck for partial credit.
#
# •	Written responses will be evaluated for their clarity, specificity, and depth. These are subjective measures so if you are in doubt, you can get feedback on your response from the TA or instructor.
#
# •	Save your responses in a local copy of this notebook with filename = <yourname.ipnb> and submit this as an attachment through Sakai.

# %% [markdown]
# ### **Question 1:**
#  What are ways in which artificial neural networks (ANNs) help us understand brain function? What are aspects of brain function that they do not provide good explanations for? [Note: there are many types of ANNs, here we refer to the most common one, which we discussed in class: the ‘multilayer perceptron’.] *(10 points)*

# %% [markdown]
# Following the formatting seen above in the markdown text cells, write your answer below.
#
# > Write your response here:

# %% [markdown]
# ### **Question 2:**
#
# You receive a message consisting of a steady stream of binary tokens.
#
# a.	Write a function my_entropy that reads the message and returns the Shannon entropy of the message (assuming a string length of 4). This function estimates how informative (surprising) the message is expected to be if we were to receive more samples from it. *(10 points)*

# %%
def my_entropy():

# %% [markdown]
# b.	Write four functions that return a message of length N=20 that, according to my_entropy prints,
#
#       i.   Is uninformative
#
#       ii.  Is highly informative
#
#       iii. Is somewhat informative
#
#       iv.  Seems highly informative, but is completely uninformative to a receiver who sees how the function generates the message

# %%
#write funcions here

# %% [markdown]
# ### **Question 3:**
#
# Download the CSV for this question.
#
# Imagine you are teaching a class of 12 students. They rate their experience with biology, research, and programming on a scale of 1 to 5. You want to divide these students into 4 groups of 3 so that the groups are well-matched in experience *(10 points)*.

# %%
csv.file=pd.read_csv('directory/ csv stored file name')
#return the vector output here

# %% [markdown]
# a. Describe in words an objective function whose minimum provides the best grouping of students. What assumptions does this function make?

# %% [markdown]
# > Write response here:

# %% [markdown]
# b. Can you calculate the gradient or optimum of this function? If so, what is it? If not, why not?

# %% [markdown]
# > Write response here:

# %% [markdown]
# c. Implement the objective function and an algorithm to find good groups based on this function. The function should take as input the data from the csv file of experience ratings and output a 12 x 1 vector containing each subject’s group assignment.

# %%
#implement objective function

# %% [markdown]
# ### **Question 4**:
#
# ##### Consider a robot that has two sensor arrays, one on each side. Its job is to determine whether a stimulus is presented to the left or right side *(30 points)*.
#
# ##### a.	Write a function my_regress that takes as its arguments the number of trials T and the number of sensors S in the array (assume each array has S sensors).
# *(hint: be sure to import needed packages)*
#
#
# i.Define a binary vector y of length T, representing the side which the stimulus is presented on. The two sides should activate with similar probability.
#
# ii.	Define an array X that represents the activation of each sensor on each trial. Sensor activity increases by 1 unit if it is on the side of the stimulus and is unchanged otherwise. All sensors also experience additive noise sampled from a gaussian distribution with standard deviation of 1.
#
# iii.	Recenter y and X.
#
# iv.	Using the first T/2 samples as ‘training data’, perform a multivariate linear regression to learn a weight vector w for estimating y from X.
#
# v.	Define a binary vector z that contains the robot’s prediction of which side each stimulus is presented on.
#
#  vi.	Using y and z, determine the mean-squared error for the training and testing data as mse_tr and mse_te, respectively.
#
# vii.	Return w, mse_tr, and mse_te.

# %%
#define vector here 
y =

# define array here 
x = 

#recenter here

#split data and perform a linear regression

#define a binary vector
z = 

#calculate mean-square error
mse_tr = 
mse_te = 

#return values
# Out:
#   File "<ipython-input-1-5844231ddf38>", line 2
#     y =
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# b.	Call the function my_regress for T = 1000 and S = 1 and 50.

# %%
#call my_regress given specific parameters

# %% [markdown]
# i. Plot 'w' for each S and explain the output that you see.

# %%
#import needed packages and create a graph

# %% [markdown]
# > Write response here:

# %% [markdown]
# ii.	Given the ‘w’ that is learned for S = 1, what are the directions in which the system is most and least susceptible to noise (ie most likely to erroneously estimate stimulus location)? Explain why this is in terms of the dot product.

# %% [markdown]
# > Write response here:

# %% [markdown]
# iii.	Plot mse_tr and mse_te for each S. Explain the difference in MSE between S = 1 and S = 50, referring to ‘signal’, ‘noise’, and ‘dot product’.

# %%
#plot mse_tr and mse_te

# %% [markdown]
# > Write response here:

# %% [markdown]
# iv.	What is the smallest value of S for which mse_tr is guaranteed to be 0? What happens to mse_te and w at this value and why?

# %% [markdown]
# > Write response here:

# %% [markdown]
# ### **Question 5**
#
# Propose a modeling question (as prescribed by the “How to Model” paper) that explores the illusion presented on the following page and hypothesize an answer. Which of Marr’s levels of analysis does your question probe? (10 points; note that this illusion relies on color perception; please let the TA or instructor know if you cannot see the effect).
#
# Review the image here: https://petapixel.com/2019/07/31/this-black-and-white-photo-uses-color-grid-lines-to-trick-your-brain/

# %% [markdown]
# ![blackandwhitetrick-800x535.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# > Write response here:
